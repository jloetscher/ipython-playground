# %%
# %matplotlib inline

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

matplotlib.style.use('ggplot')

# %% [markdown]
# First read the recommendations table from the csv file.

# %%
dfRecommendations = pd.DataFrame.from_csv("./smartvote-light-recommendations-2018-02-25.csv")

# %% [markdown]
# # Analyse Recommendations per Election
#
# Display the number of recommendations per Election

# %%
dfRecommendations.groupby("electionId").voterId.count().plot.barh()

# %% [markdown]
# Display the number of unique voterId's that created a recommendation

# %%
dfRecommendations.groupby("electionId").voterId.nunique().plot.barh()
